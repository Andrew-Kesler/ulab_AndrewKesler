# %% [markdown]
# # HW 12 - Introduction to Pandas
# ULAB - Physics and Astronomy Division \
# Due **Sunday, February 9th, 2025 at 11:59pm** on Gradescope

# %% [markdown]
# ------
# ## 0 Academic Integrity
# Please type the following message in the cell below as a comment. Sign with your name.
#
# ------
# **I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.**
#
# ------

# %%
# I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment.
# All work submitted is my own and reflects my understanding of the material.
# -Andrew Kesler

# %% [markdown]
# ------
# ## 1 Real Exoplanet Data!
# Start by importing `pandas` into your Jupyter notebook.

# %%
import pandas as pd
data = pd.read_csv('C:/Users/Andrew/Downloads/exoplanet_data (1).csv', comment='#')

# %% [markdown]
# With a pandas dataframe, import the `exoplanet_data.csv` file. If you are curious this data is pulled directly from: https://exoplanetarchive.ipac.caltech.edu/. Due to the formating you will want to add the argument `comment='#'` to statement.

# %%
print(data.columns)
# Out:
# Index(['pl_name', 'hostname', 'default_flag', 'sy_snum', 'sy_pnum',
#        'discoverymethod', 'disc_year', 'disc_facility', 'soltype',
#        'pl_controv_flag', 'pl_refname', 'pl_orbper', 'pl_orbpererr1',
#        'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1',
#        'pl_orbsmaxerr2', 'pl_orbsmaxlim', 'pl_rade', 'pl_radeerr1',
#        'pl_radeerr2', 'pl_radelim', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2',
#        'pl_radjlim', 'pl_bmasse', 'pl_bmasseerr1', 'pl_bmasseerr2',
#        'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2',
#        'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccen', 'pl_orbeccenerr1',
#        'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_insol', 'pl_insolerr1',
#        'pl_insolerr2', 'pl_insollim', 'pl_eqt', 'pl_eqterr1', 'pl_eqterr2',
#        'pl_eqtlim', 'ttv_flag', 'st_refname', 'st_spectype', 'st_teff',
#        'st_tefferr1', 'st_tefferr2', 'st_tefflim', 'st_rad', 'st_raderr1',
# ...

# %% [markdown]
# Print the headers of your dataframe.

# %%
print(list(data.columns))
# Out:
# ['pl_name', 'hostname', 'default_flag', 'sy_snum', 'sy_pnum', 'discoverymethod', 'disc_year', 'disc_facility', 'soltype', 'pl_controv_flag', 'pl_refname', 'pl_orbper', 'pl_orbpererr1', 'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1', 'pl_orbsmaxerr2', 'pl_orbsmaxlim', 'pl_rade', 'pl_radeerr1', 'pl_radeerr2', 'pl_radelim', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2', 'pl_radjlim', 'pl_bmasse', 'pl_bmasseerr1', 'pl_bmasseerr2', 'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2', 'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccen', 'pl_orbeccenerr1', 'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_insol', 'pl_insolerr1', 'pl_insolerr2', 'pl_insollim', 'pl_eqt', 'pl_eqterr1', 'pl_eqterr2', 'pl_eqtlim', 'ttv_flag', 'st_refname', 'st_spectype', 'st_teff', 'st_tefferr1', 'st_tefferr2', 'st_tefflim', 'st_rad', 'st_raderr1', 'st_raderr2', 'st_radlim', 'st_mass', 'st_masserr1', 'st_masserr2', 'st_masslim', 'st_met', 'st_meterr1', 'st_meterr2', 'st_metlim', 'st_metratio', 'st_logg', '
# ...

# %% [markdown]
# Print the columns of your dataframe as a list.

# %%
print(data['pl_name'])
# Out:
# 0          eps Ind A b
# 1             AU Mic b
# 2             AU Mic c
# 3         BD-14 3065 b
# 4           DS Tuc A b
# 5            GJ 1252 b
# 6          HD 101581 b
# 7        HD 202772 A b
# 8          HIP 67522 b
# 9    IRAS 04125+2902 b
# Name: pl_name, dtype: object

# %% [markdown]
# Print the row of the dataframe called "pl_name", this stands for *planet name*.

# %%
print(data['pl_name'].nunique())
# Out:
# 10

# %% [markdown]
# Print how many planets there are.

# %%
print(data.columns)
# Out:
# Index(['pl_name', 'hostname', 'default_flag', 'sy_snum', 'sy_pnum',
#        'discoverymethod', 'disc_year', 'disc_facility', 'soltype',
#        'pl_controv_flag', 'pl_refname', 'pl_orbper', 'pl_orbpererr1',
#        'pl_orbpererr2', 'pl_orbperlim', 'pl_orbsmax', 'pl_orbsmaxerr1',
#        'pl_orbsmaxerr2', 'pl_orbsmaxlim', 'pl_rade', 'pl_radeerr1',
#        'pl_radeerr2', 'pl_radelim', 'pl_radj', 'pl_radjerr1', 'pl_radjerr2',
#        'pl_radjlim', 'pl_bmasse', 'pl_bmasseerr1', 'pl_bmasseerr2',
#        'pl_bmasselim', 'pl_bmassj', 'pl_bmassjerr1', 'pl_bmassjerr2',
#        'pl_bmassjlim', 'pl_bmassprov', 'pl_orbeccen', 'pl_orbeccenerr1',
#        'pl_orbeccenerr2', 'pl_orbeccenlim', 'pl_insol', 'pl_insolerr1',
#        'pl_insolerr2', 'pl_insollim', 'pl_eqt', 'pl_eqterr1', 'pl_eqterr2',
#        'pl_eqtlim', 'ttv_flag', 'st_refname', 'st_spectype', 'st_teff',
#        'st_tefferr1', 'st_tefferr2', 'st_tefflim', 'st_rad', 'st_raderr1',
# ...

# %% [markdown]
# Make a new variable called `planet_data`. With a dataframe assign the variable the columns associated with the planet's names, planet's Earth radii, planet's Jupiter masses and planet's equilibrium temperatures. *Hint: It should look something like, `['pl_name', 'RADII', 'MASS', 'TEMPERATURE']` but with the proper column names.*

# %%
planet_data = data[['pl_name', 'pl_rade', 'pl_bmassj', 'pl_eqt']]

# %% [markdown]
# Print your new `planet_data` variable.

# %%
print(planet_data)
# Out:
#              pl_name  pl_rade  pl_bmassj  pl_eqt
# 0        eps Ind A b      NaN    6.31000   275.0
# 1           AU Mic b    3.957        NaN   600.0
# 2           AU Mic c    2.522        NaN   459.0
# 3       BD-14 3065 b   21.590   12.37000  2001.0
# 4         DS Tuc A b    5.700        NaN   850.0
# 5          GJ 1252 b    1.193    0.00415     NaN
# 6        HD 101581 b    0.956        NaN   834.0
# 7      HD 202772 A b   17.318    1.01700  2132.0
# 8        HIP 67522 b    9.987        NaN  1175.0
# 9  IRAS 04125+2902 b   10.738        NaN   854.0

# %% [markdown]
# ------
# ## 2 Plotting
# Make a scatter plot of **exoplanet Earth radius vs. equilibrium temperatures**. Include units, x/y axis labels, and a legend.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(planet_data['pl_rade'], planet_data['pl_eqt'], alpha=0.5)
plt.title('Exoplanet Earth Radius vs. Equilibrium Temperature')
plt.xlabel('Earth Radius (Earth units)')
plt.ylabel('Equilibrium Temperature (K)')
plt.grid(True)
plt.show()

# %% [markdown]
# What trend do you notice in the data? Does it have positive or negative correlation?

# %%
# Comment on the observed trend in the scatter plot of Exoplanet Earth Radius vs. Equilibrium Temperature:
# The scatter plot does not indicate a clear positive or negative correlation between the Earth radius of exoplanets
# and their equilibrium temperatures. Temperatures vary widely across the different sizes, suggesting that factors
# other than size, such as atmospheric composition, orbital distance from the star, and star type, likely play
# a more significant role in determining the equilibrium temperatures of these planets.

# %% [markdown]
# ------
# ## 3 A "Cool" Planet
# What planet has the **lowest** equilibrium temperature? Print the planet name and temperature with your `planet_data` variable.

# %%
coolest_planet = planet_data[planet_data['pl_eqt'] == planet_data['pl_eqt'].min()]
print(f"The coolest planet is {coolest_planet['pl_name'].iloc[0]} with a temperature of {coolest_planet['pl_eqt'].iloc[0]} K.")
# Out:
# The coolest planet is eps Ind A b with a temperature of 275.0 K.

# %% [markdown]
# Make a new variable that only contains the information for that planet. \
# \
# *Hint: Use the `.iloc[[#]]` function. Replace # with the proper index.*

# %%
coolest_planet_info = coolest_planet.iloc[0]
print(coolest_planet_info)
# Out:
# pl_name      eps Ind A b
# pl_rade              NaN
# pl_bmassj           6.31
# pl_eqt             275.0
# Name: 0, dtype: object

# %% [markdown]
# Print the number of columns in the row.

# %%
print("Number of columns in the row:", len(coolest_planet_info))
# Out:
# Number of columns in the row: 4

# %% [markdown]
# Make a new variable that contains only the columns WITHOUT `Nan` values. *Hint: You can use the function `.dropna(axis=1)`.*

# %%
clean_data = planet_data.dropna(axis=1)

# %% [markdown]
# Print how many columns you have now.

# %%
print("Number of columns:", clean_data.shape[1])
# Out:
# Number of columns: 1

# %% [markdown]
# Download this paper: https://www.nature.com/articles/s41586-024-07837-8. What is the title of this paper?

# %%
# A temperate super-Jupiter imaged with JWST in the mid-infrared

# %% [markdown]
# What are the main conclusions from the paper? Do you trust their methods? Why would they be questionable?

# %%
# A temperate super-Jupiter imaged with JWST in the mid-infrared
# The main conclusions from the paper include the direct imaging of a cold, Jupiter-sized exoplanet
# using JWST with temperatures around 275 K, exhibiting features that might suggest a high metallicity
# and high carbon-to-oxygen ratio atmosphere. The methods, which involved coronagraphic imaging with JWST,
# are trustworthy due to rigorous data analysis including cross-verification with archival data
# and consistency with theoretical models, although they note an unexpected source location
# that adds a minor element of uncertainty to the conclusions.

# %% [markdown]
# The planet with the **lowest effective temperature** from your `exoplanet_data.csv` file should match the planet from the paper you just downloaded. What values for the `.csv` file match the ones in the paper?

# %%
min_temp_in_paper = 275  # temperature in Kelvin as reported in the paper
min_temp_from_data = exoplanet_data['TEMPERATURE'].min()
if min_temp_from_data == min_temp_in_paper:
    print("The temperatures match.")
else:
    print(f"Data temperature {min_temp_from_data} K does not match paper temperature {min_temp_in_paper} K.")

# %% [markdown]
# Which values from the `.csv` file I provided you DON'T match the ones from the paper?

# %%
non_matching_temps = exoplanet_data[exoplanet_data['TEMPERATURE'] != 275]
print(f"Values not matching 275 K from the paper:\n{non_matching_temps}")

# %% [markdown]
# In the paper, find the age of the planet. What is the age, with error, of the planet?

# %%
age = "3.5 - 5.7 Gyr"
print(f"The age of the planet is estimated to be within the range of {age}.")

# %% [markdown]
# Create a new column called `Age` with your new variable and assign it the proper value.

# %%
age_value = "3.5 to 5.7 Gyr"
exoplanet_data['Age'] = age_value
print(exoplanet_data.head())

# %% [markdown]
# ## 4 Make a New `.csv` File

# %% [markdown]
# To a new `.csv` file, save the planet WITHOUT the Nan rows and WITH the `Age` column added.

# %%
cleaned_data = exoplanet_data.dropna().reset_index(drop=True)
csv_file_path = 'path/to/save/your_new_file.csv'  # Specify your path
cleaned_data.to_csv(csv_file_path, index=False)
print(f"Data saved to {csv_file_path}")

# %% [markdown]
# Turn in this jupyter notebook to gradescope with your NEW `.csv` file.
